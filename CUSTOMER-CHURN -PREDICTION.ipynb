# %% [markdown]
# ### Importing Libraries

# %%
import numpy as mp
import pandas as pd
import seaborn as sb
import matplotlib.ticker as tick
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading CSV File

# %%
churn = pd.read_csv("Churn.csv")

# %%
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Data Analysis

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.columns.values
# Out:
# array(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'], dtype=object)

# %%
churn.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
churn.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          0 non-null      float64
#  3   CreditScore      10000 non-null  int64
#  4   Geography        0 non-null      float64
#  5   Gender           0 non-null      float64
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(5), int64(9)
# memory usage: 1.1 MB

# %%
churn.Surname = pd.to_numeric(churn.Surname, errors='coerce')
churn.Geography = pd.to_numeric(churn.Surname, errors='coerce')
churn.Gender = pd.to_numeric(churn.Surname, errors='coerce')
churn.isnull().sum()
# Out:
# RowNumber              0
# CustomerId             0
# Surname            10000
# CreditScore            0
# Geography          10000
# Gender             10000
# Age                    0
# Tenure                 0
# Balance                0
# NumOfProducts          0
# HasCrCard              0
# IsActiveMember         0
# EstimatedSalary        0
# Exited                 0
# dtype: int64

# %%
# Dropping the null values
churn.dropna()
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
churn = churn.drop(columns= ['Surname', 'Geography', 'Gender'])
churn
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# ...

# %%
plt.figure(figsize=(12,12))
sb.heatmap(churn.corr(), cmap="Paired")
# Out:
# <Axes: >

# %%
pip install --upgrade imbalanced-learn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Model Building

# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
churn = pd.read_csv('Churn.csv')

# %%
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
churn = churn.drop(columns= ['Surname', 'Geography', 'Gender'])
churn
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# ...

# %% [markdown]
# ### Splitting Train and Test Data

# %%
x = churn.drop('Exited', axis=1)
x
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0                 1          1               1        101348.88
# ...

# %%
y = churn['Exited']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state= 21)

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
dt.score(x_test, y_pred)
# Out:
# 1.0

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      2393
#            1       0.47      0.51      0.49       607
#
#     accuracy                           0.78      3000
#    macro avg       0.67      0.68      0.68      3000
# weighted avg       0.79      0.78      0.79      3000

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2041  352]
#  [ 297  310]]

# %% [markdown]
# ### Smote

# %%
smote_enn = SMOTEENN()
x_resampled, y_resampled = smote_enn.fit_resample(x, y)

# %%
xr_train, xr_test, yr_train, yr_test = train_test_split(x_resampled, y_resampled, test_size = 0.2)

# %%
dt_smote = DecisionTreeClassifier(criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
dt_smote.fit(xr_train, yr_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred_smote = dt_smote.predict(xr_test)

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      2393
#            1       0.47      0.51      0.49       607
#
#     accuracy                           0.78      3000
#    macro avg       0.67      0.68      0.68      3000
# weighted avg       0.79      0.78      0.79      3000

# %%
print(confusion_matrix(yr_test, y_pred_smote))
# Out:
# [[436 210]
#  [ 81 916]]

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_smote = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)
rf_smote.fit(x_train, y_train)
y_pred_rf = rf_smote.predict(x_test)

# %%
print(classification_report(y_test, y_pred_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      2393
#            1       0.81      0.39      0.53       607
#
#     accuracy                           0.86      3000
#    macro avg       0.84      0.68      0.72      3000
# weighted avg       0.85      0.86      0.84      3000

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[2338   55]
#  [ 370  237]]

# %%
smote_enn = SMOTEENN()
x_resampled_rf, y_resampled_rf = smote_enn.fit_resample(x, y)

# %%
xr_train, xr_test, yr_train, yr_test = train_test_split(x_resampled_rf, y_resampled_rf, test_size = 0.2)

# %%
rf_smote_model = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
rf_smote_model.fit(xr_train, yr_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred_smote_rf = rf_smote_model.predict(xr_test)

# %%
print(classification_report(y_test, y_pred_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      2393
#            1       0.81      0.39      0.53       607
#
#     accuracy                           0.86      3000
#    macro avg       0.84      0.68      0.72      3000
# weighted avg       0.85      0.86      0.84      3000

# %%
print(confusion_matrix(yr_test, y_pred_smote_rf))
# Out:
# [[444 204]
#  [ 87 929]]
